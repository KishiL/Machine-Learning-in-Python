# %%
import pandas as pd
import numpy as np
import plotly
import pylab
print('Plotly:', plotly. __version__)
plotly.offline.init_notebook_mode()
import plotly
#plotly.tools.set_credentials_file(username='kishiw2s', api_key='liyue2658'
# Out:
# Plotly: 1.12.7
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.16.2
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
df = pd.read_table('avocado.csv',sep=',',index_col=0)
#df["Date"]=pd.to_datetime(df["Date"])
#df.drop(df.columns[1],axis=1)
ustotal=df.loc[(df.region=='TotalUS')]
allregion=df.loc[(df.region != 'TotalUS')]

# %%
ustotal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 338 entries, 0 to 11
# Data columns (total 13 columns):
# Date            338 non-null object
# AveragePrice    338 non-null float64
# Total Volume    338 non-null float64
# 4046            338 non-null float64
# 4225            338 non-null float64
# 4770            338 non-null float64
# Total Bags      338 non-null float64
# Small Bags      338 non-null float64
# Large Bags      338 non-null float64
# XLarge Bags     338 non-null float64
# type            338 non-null object
# year            338 non-null int64
# region          338 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 37.0+ KB

# %%
df.head(10)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# 5  2015-11-22          1.26      55979.78  1184.27   48067.99   43.61
# 6  2015-11-15          0.99      83453.76  1368.92   73672.72   93.26
# 7  2015-11-08          0.98     109428.33   703.75  101815.36   80.00
# 8  2015-11-01          1.02      99811.42  1022.15   87315.57   85.34
# 9  2015-10-25          1.07      74338.76   842.40   64757.44  113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# ...

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
print(df.dtypes)
print('===========')
print(df.info())
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object
# ...
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18249 entries, 0 to 11
# Data columns (total 13 columns):
# Date            18249 non-null object
# AveragePrice    18249 non-null float64
# Total Volume    18249 non-null float64
# 4046            18249 non-null float64
# 4225            18249 non-null float64
# 4770            18249 non-null float64
# Total Bags      18249 non-null float64
# Small Bags      18249 non-null float64
# Large Bags      18249 non-null float64
# XLarge Bags     18249 non-null float64
# type            18249 non-null object
# year            18249 non-null int64
# region          18249 non-null object
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)
# %matplotlib inline 
import missingno as mn
mn.matrix(df.sort_values(by=["Date","AveragePrice","region",]))

# %%
#explanation of no missing value

# %% [markdown]
# It appears that there is no missing value in this data set.
# Explain why
# data source: weekly collected from cashier

# %%
df_grouped = df.groupby(by=['type'])
print (df_grouped.describe())
# Out:
#                 4046                                                 \
#                count           mean           std    min        25%
# type
# conventional  9126.0  578611.649925  1.742501e+06  72.06  31935.380
# organic       9123.0    7311.281600  2.350155e+04   0.00    157.915
#
#                                                      4225                 \
#                      50%         75%          max   count           mean
# type
# conventional  104706.745  364716.870  22743616.17  9126.0  574805.318859
# organic          911.460    4354.415    361996.84  9123.0   15411.857724
#
#                ...   XLarge Bags               year                         \
#                ...           75%        max   count         mean       std
# type           ...
# conventional   ...      2409.215  551693.65  9126.0  2016.147929  0.939968
# organic        ...         0.000     510.41  9123.0  2016.147868  0.939961
#
#
#                  min     25%     50%     75%     max
# ...

# %% [markdown]
# Data Visualization

# %%
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)

# %matplotlib inline 
import seaborn as sns
cmap = sns.diverging_palette(220, 10, as_cmap=True)
print('Matplotlib:', matplotlib. __version__)
# could also say "%matplotlib notebook" here to make things interactive
# Out:
# Matplotlib: 2.2.2

# %%
#Distribution for us average price
sns.set(font_scale=1.5) 
from scipy.stats import norm
fig, ax = plt.subplots(figsize=(15, 9))
sns.distplot(a = allregion.AveragePrice, kde=False, fit=norm,color="g")

# %% [markdown]
# The distribution plot above is

# %%
#correlation plot
cmap = sns.set(style="darkgrid") # one of the many styles to plot using
f, ax = plt.subplots(figsize=(10, 10))
#sns.heatmap(df.corr(), cmap=cmap, annot=True)
sns.heatmap(df.corr(), cmap="Greens",annot=True)
f.tight_layout()

# %%
import seaborn as sns
sns.set()
import matplotlib
import matplotlib.pyplot as plt

# %%
#fig, ax = plt.subplots(figsize=(10,10))
#sns.swarmplot(x="Total Volume", y="AveragePrice", hue="type", data=df)
#plt.title('Type Prices')
#plt.show()
#%matplotlib inline

# %%
g = sns.factorplot('AveragePrice','region',data=allregion,
                   hue='year',
                   height=18,
                   aspect=0.7,
                   palette='Greens',
                   join=False,
              )
# Out:
# /Users/mac/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3666: UserWarning:
#
# The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.

# %%
plt.figure(figsize=(20,13))
sns.scatterplot(x='Total Volume', y = 'AveragePrice', hue= 'year', data= allregion,palette ="Set2")

# %%
plt.figure(figsize=(14,10))
sns.boxplot(y="type", x="AveragePrice", data=allregion, palette = "Set2")

# %%
allregion.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225           4770  \
# count  17911.000000  1.791100e+04  1.791100e+04  1.791100e+04   17911.000000
# mean       1.407619  5.392587e+05  1.838074e+05  1.882231e+05   14551.234381
# std        0.404253  1.224332e+06  5.151059e+05  4.519856e+05   48817.536762
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00       0.000000
# 25%        1.100000  1.057102e+04  8.196600e+02  2.909610e+03       0.000000
# 50%        1.370000  1.001541e+05  7.824430e+03  2.670199e+04     164.230000
# 75%        1.670000  4.001767e+05  1.014888e+05  1.317552e+05    5736.735000
# max        3.250000  1.127475e+07  5.160897e+06  5.402444e+06  804558.250000
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.791100e+04  1.791100e+04  1.791100e+04   17911.000000  17911.000000
# mean   1.526757e+05  1.162029e+05  3.450569e+04    1967.168041   2016.147898
# ...

# %%
allregion['Year'], allregion['Month'],  allregion['Day'] = allregion['Date'].str.split('-').str
variant = allregion[['4046', '4225', '4770']].groupby(allregion.Month).sum()
#x = df[['4046', '4225', '4770']]
#y = df.Month.sum()
plt.figure(figsize=(15,10))
type1=variant['4046']
type2=variant['4225']
type3=variant['4770']
pylab.plot(type1,label="4046")
pylab.plot(type2,label="4225")
pylab.plot(type3,label="4770")
pylab.legend()
pylab.ylabel("Volume")
pylab.xlabel("Month")
#plot(kind='line', fontsize = 15, figsize=(15,10))
# Out:
# /Users/mac/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Text(0.5,0,'Month')

# %%
from sklearn.ensemble import RandomForestClassifier

# Set random seed
np.random.seed(0)
data_with_categories=pd.get_dummies(allregion.drop(columns=['Date'],axis=1))
x=data_with_categories.drop(columns='AveragePrice', axis=1)
y=data_with_categories['AveragePrice']
x.describe()
# Out:
#        Total Volume          4046          4225           4770    Total Bags  \
# count  1.791100e+04  1.791100e+04  1.791100e+04   17911.000000  1.791100e+04
# mean   5.392587e+05  1.838074e+05  1.882231e+05   14551.234381  1.526757e+05
# std    1.224332e+06  5.151059e+05  4.519856e+05   48817.536762  3.645992e+05
# min    8.456000e+01  0.000000e+00  0.000000e+00       0.000000  0.000000e+00
# 25%    1.057102e+04  8.196600e+02  2.909610e+03       0.000000  4.905195e+03
# 50%    1.001541e+05  7.824430e+03  2.670199e+04     164.230000  3.755102e+04
# 75%    4.001767e+05  1.014888e+05  1.317552e+05    5736.735000  1.036916e+05
# max    1.127475e+07  5.160897e+06  5.402444e+06  804558.250000  4.145407e+06
#
#          Small Bags    Large Bags    XLarge Bags          year  \
# count  1.791100e+04  1.791100e+04   17911.000000  17911.000000
# mean   1.162029e+05  3.450569e+04    1967.168041   2016.147898
# std    2.787596e+05  1.139477e+05    8186.402196      0.939939
# ...

# %%
allregion.head()
print(allregion.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17911 entries, 0 to 11
# Data columns (total 16 columns):
# Date            17911 non-null object
# AveragePrice    17911 non-null float64
# Total Volume    17911 non-null float64
# 4046            17911 non-null float64
# 4225            17911 non-null float64
# 4770            17911 non-null float64
# Total Bags      17911 non-null float64
# Small Bags      17911 non-null float64
# Large Bags      17911 non-null float64
# XLarge Bags     17911 non-null float64
# type            17911 non-null object
# year            17911 non-null int64
# region          17911 non-null object
# Year            17911 non-null object
# Month           17911 non-null object
# Day             17911 non-null object
# dtypes: float64(9), int64(1), object(6)
# memory usage: 2.9+ MB
# None

# %%
np.random.seed(0)
x=allregion.drop(columns='AveragePrice', axis=1).values
y=allregion['AveragePrice'].values.ravel()

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
print(Xtrain.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14328 entries, 46 to 2
# Data columns (total 15 columns):
# Date            14328 non-null object
# Total Volume    14328 non-null float64
# 4046            14328 non-null float64
# 4225            14328 non-null float64
# 4770            14328 non-null float64
# Total Bags      14328 non-null float64
# Small Bags      14328 non-null float64
# Large Bags      14328 non-null float64
# XLarge Bags     14328 non-null float64
# type            14328 non-null object
# year            14328 non-null int64
# region          14328 non-null object
# Year            14328 non-null object
# Month           14328 non-null object
# Day             14328 non-null object
# dtypes: float64(8), int64(1), object(6)
# memory usage: 1.7+ MB
# None

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
clf = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=1, n_estimators=150))
scores = cross_val_score(clf, Xtrain, Ytrain, cv=3, n_jobs=-1)
#print(f"{round(np.mean(scores),3)*100}% accuracy")

#clf.fit(Xtrain,Ytrain)

#print(mean_squared_error(y_pred=clf.predict(Xtest), Y_true=Ytest))
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/Users/mac/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py", line 350, in __call__
#     return self.func(*args, **kwargs)
#   File "/Users/mac/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 131, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mac/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py", line 131, in <listcomp>
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#   File "/Users/mac/anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py", line 458, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
# ...

# %%
clf
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('randomforestregressor', RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=1,
#            oob_score=False, random_state=1, verbose=0, warm_start=False))])
